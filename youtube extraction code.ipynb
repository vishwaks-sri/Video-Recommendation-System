# %%
# import libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Google API Python Client

# %% [markdown]
# Google API Python Client or apiclient which is a python client to interact with the Google APIs in an easier way. In order to use the API, we need to build a resource object for the API. We passed the service name, its version and our Developer(or API) key to build method of apiclient.discovery module.

# %%
from apiclient.discovery import build

# %%
# arguments to be passed to build function
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"
DEVELOPER_KEY = "AIzaSyChke7YheMJwLgNNc_CYRCV-Noyis2soOk"

# create youtube resource object for interacting with API
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

# %% [markdown]
# We will use search.list function and pass in the query parameters. YouTube API will return a collection of search results that match the query parameters specified in the API request. By default, a search result set identifies matching video, channel, and playlist resources, but you can also configure queries to only retrieve a specific type of resource. More info at https://developers.google.com/youtube/v3/docs/search/list

# %%
# query parameters
query=input("Enter the video you want to view: ")
part = "id,snippet"
maxresults = "50"
type = "video"
order = "relevance"

# calling the search.list method to retrieve youtube search results
search_response = youtube.search().list(q = query, 
                                            part = part,
                                            maxResults = maxresults,
                                            order = order,
                                            type = type).execute()
# Out:
# Enter the video you want to view: INDIA

# %%
# take a look at the JSON object returned by YouTube
search_response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'ZICqVKw6jn3XurXQGPbIl44heyE',
#  'id': {'kind': 'youtube#video', 'videoId': 'dLAgSz7sEMg'},
#  'snippet': {'publishedAt': '2021-05-30T12:30:09Z',
#   'channelId': 'UCpEhnqL0y41EpW2TvWAHD7Q',
#   'title': 'क्यों रो पड़ा Pawandeep अपनी Singing के वक़्त? | Indian Idol | Contestant Mashup',
#   'description': 'Click here to Subscribe to SET India: https://www.youtube.com/channel/UCpEhnqL0y41EpW2TvWAHD7Q?sub_confirmation=1 Click here to enjoy all the clips ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dLAgSz7sEMg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/dLAgSz7sEMg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/dLAgSz7sEMg/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'SET India',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2021-05-30T12:30:09Z'}}

# %%
# extract the results from search response
results = search_response.get("items", [])

# %%
# extract the video ids from the results of search response
video_ids = []

for search_result in results:
    if search_result["id"]["kind"] == "youtube#video":
        video_ids.append(search_result["id"]["videoId"])

# %%
# convert the list of videos into a string separated by commas using join function
video_ids = ",".join(video_ids)
video_ids
# Out:
# 'dLAgSz7sEMg,U5CphAfjNV4,L2wEMs7_nuA,HIlB3GvqBFE,n-wvjG3PKew,peRpQi0JlSI,TR8P0If1tlk,td5HiD_gGXY,lxzBw_Q0gNs,IgAnj6r1O48,XnqDBGPK3Xg,IZHlPpJPKiA,gSqfdw9QtPw,wdkCmVKszFA,eiOLjbtXzUs,Cyww9jdOlLE,QvjoEqzMP4k,j_DnnRwTOWQ,UsKG7W6HaUo,XW-HSXSM4nw,5J_5OOsChSY,-B9aPCYUCjs,3Q2SssqR3mY,XYqqncmBKrQ,YXHfhU-gM1A,et2a_nyZvAw,tNW_gJVojKg,penRbyYJPOo,nIz-4Md8OH4,eGUG2icJS2w,8YQLEUBLJvo,RHMm_rNx0oM,lmxPn1aCDMY,zBVAexI3sxI,Q73nrvjloHo,Gfqfy8DdHD4,UIps1tZSOOI,bu29jCx3UuQ,5I9V4J4tM44,EMoxx66CHME,KwiuQFRoNhA,5pLhmE8z5cw,44EMYO14Blw,-ay1SWaDq-c,m2exrWvaVDk,bTj1JcrKOYA,BBaIQOvScK4,zyKu7DxzcR4,a_kkh-Rxp9k,RTZrvGILxfE'

# %%
# call the videos().list method to retrieve the statistics for each video
videos_response = youtube.videos().list(
 id=video_ids,
 part='snippet,statistics'
).execute()

# %%
# extract the required information as dictionary and then store them into a list of dictionary
res = []
for i in videos_response['items']:
    temp_res = dict(v_id = i['id'], v_title = i['snippet']['title'])
    temp_res["publishedAt"] = i["snippet"]["publishedAt"][:10]
    temp_res["description"] = i["snippet"]["description"]
    temp_res.update(i['statistics'])
    res.append(temp_res)

# %%
# convert the list of dictionary into a pandas DataFrame
dataframe = pd.DataFrame.from_dict(res)
dataframe['Category'] ='INDIA'
dataframe
# Out:
#            v_id                                            v_title  \
# 0   dLAgSz7sEMg  क्यों रो पड़ा Pawandeep अपनी Singing के वक़्त? |...
# 1   U5CphAfjNV4  India Alert - इंडिया अलर्ट | New Episode 530 |...
# 2   L2wEMs7_nuA  COVID-19 India: Guru Baba Ramdev sparks adulat...
# 3   HIlB3GvqBFE  Jacky ने Enjoy किया Pawandeep के Performance क...
# 4   n-wvjG3PKew  India electric vehicles: Initiative reveals ne...
# 5   peRpQi0JlSI  Unlock In India : देश मे शुरू हुआ Corona का Do...
# 6   TR8P0If1tlk  India में Facebook, Twitter जैसे Social networ...
# 7   td5HiD_gGXY  India’s poorest suffer Covid with almost no he...
# 8   lxzBw_Q0gNs  India economic crisis: Millions pushed into po...
# 9   IgAnj6r1O48    10 Best Places to Visit in India - Travel Video
# 10  XnqDBGPK3Xg  Hongo negro: 5 preguntas sobre la rara infecci...
# 11  IZHlPpJPKiA  India: PM Modi led BJP Govt completes 7 Years ...
# 12  gSqfdw9QtPw  India battles black fungus infections alongsid...
# 13  wdkCmVKszFA  100% Automobile Import Ban ! Biggest Investmen...
# 14  eiOLjbtXzUs  Indian Defence Updates : Super Sukhoi Engine O...
# 15  Cyww9jdOlLE  “I’m fine, really”: How I found hope as Covid ...
# 16  QvjoEqzMP4k  Hema Ji हुई Arunita के Performance से Mesmeriz...
# 17  j_DnnRwTOWQ         Sawaal India Ka: क्या है महंगे तेल का खेल?
# 18  UsKG7W6HaUo  COVID-19 variant first detected in India now "...
# 19  XW-HSXSM4nw  BTS Indian Interview Teaser ft. Sakshma Srivas...
# 20  5J_5OOsChSY  Hybrid of Variants Found In India & UK Identif...
# 21  -B9aPCYUCjs  Covid Cases Continue To Decline In India | Loc...
# 22  3Q2SssqR3mY  Coronavirus Update: India witnesses slight dip...
# 23  XYqqncmBKrQ  India's Railway System: Carrying 8 Billion Peo...
# 24  YXHfhU-gM1A  Mallaika की Twerking से Stage पे हुआ Blaze | I...
# 25  et2a_nyZvAw  FREE FIRE INDIA VS MENA SERVER 1 VS 1 CHAMPION...
# 26  tNW_gJVojKg  Indian Defence Updates : Su-57 Single Engine M...
# 27  penRbyYJPOo  India Alert - इंडिया अलर्ट | New Episode 528 |...
# 28  nIz-4Md8OH4  PELEO CON MI SUEGRA INDIA ⚠️ *quien cocina las...
# 29  eGUG2icJS2w  Dominos & Air India Data Leaked! | How to Prot...
# 30  8YQLEUBLJvo  Indian journalist Barkha Dutt says the COVID s...
# 31  RHMm_rNx0oM  Severe cyclone makes landfall on India coast -...
# 32  lmxPn1aCDMY  India Alert | New Episode 527 | Kalyugi Pyar -...
# 33  zBVAexI3sxI  India blocks tweets critical of Modi's handlin...
# 34  Q73nrvjloHo  महिला दारोगा और SP के स्टोनो का ऑडियो हुआ वायर...
# 35  Gfqfy8DdHD4  din bhar ki khabar | news of the day, hindi ne...
# 36  UIps1tZSOOI  CINEMA BANDI | Raj & DK | Praveen Kandregula |...
# 37  bu29jCx3UuQ    India reports thousands of "black fungus" cases
# 38  5I9V4J4tM44  COVID-19: Indian children orphaned by the pand...
# 39  EMoxx66CHME  Triple century /1000 runs ? WTC Final : Day 2 ...
# 40  KwiuQFRoNhA  Fears Indian COVID-19 variant could spread in ...
# 41  5pLhmE8z5cw  Life After IIT ft. @Flying Beast | Alma Matter...
# 42  44EMYO14Blw  din bhar ki khabar | news of the day, hindi ne...
# 43  -ay1SWaDq-c  India passes 300,000 coronavirus deaths as mas...
# 44  m2exrWvaVDk  India’s COVID Battle: The Lowest Caste On The ...
# 45  bTj1JcrKOYA  India scraps local vaccine trial plans, Japane...
# 46  BBaIQOvScK4  Deadly 'black fungus' disease infects more tha...
# 47  zyKu7DxzcR4  Whatsapp sues Indian government over privacy r...
# 48  a_kkh-Rxp9k  BATTLEGROUNDS MOBILE INDIA - PRE-REGISTER KIYA...
# 49  RTZrvGILxfE  Niños convertidos en adultos en India antes de...
#
#    publishedAt                                        description viewCount  \
# 0   2021-05-30  Click here to Subscribe to SET India: https://...      7492
# 1   2021-05-30  India Alert - इंडिया अलर्ट - New Episode 530 -...     12528
# 2   2021-05-30  Indian yoga guru Baba Ramdev’s comments on COV...     18848
# 3   2021-05-30  Click here to Subscribe to SET India: https://...     13689
# 4   2021-05-30  One of the world's most polluted cities is on ...      7039
# 5   2021-05-30  Coronavirus In India : देश में अब कोरोना के नए...     56167
# 6   2021-05-26  Read the complete story here: https://www.thel...    119354
# 7   2021-05-28  At least 300,000 people are now known to have ...    200606
# 8   2021-05-29  India has registered its lowest recorded daily...     11881
# 9   2019-05-09  Check out all the places seen in this video: h...   3556778
# 10  2021-05-27  Lo llaman el "hongo negro" y en India es consi...    995186
# 11  2021-05-30  Today (30 May) PM Modi has addressed nation th...     15604
# 12  2021-05-29  India is battling deadly infections of black f...     34243
# 13  2021-05-29  100% Automobile Import Ban ! Biggest Investmen...     41349
# 14  2021-05-29  Top 4 Indian Defence News Headlines on Today's...     86585
# 15  2021-05-30  The trauma of the unexpected second wave in In...     29920
# 16  2021-05-30  Click here to Subscribe to SET India: https://...      3636
# 17  2021-05-27  Sawaal India Ka | एक मुहावरा है 'तेल देखो तेल ...    357947
# 18  2021-05-30  England's COVID-19 vaccine rollout is one of t...     14034
# 19  2021-05-28  Indian BTS Army are you ready? Sakshma Srivast...   3196957
# 20  2021-05-30  Vietnam has discovered a new Covid-19 variant ...     12199
# 21  2021-05-30  India reports 1,65,553 new #COVID19 cases; 2,7...      7648
# 22  2021-05-30  More than 1.65 lakh new cases of Corona have b...     50229
# 23  2021-05-19  Looking for even MORE content from Simon and t...    152785
# 24  2021-05-28  Click here to Subscribe to SET India: https://...     53041
# 25  2021-05-29  FREE INDIA VS MENA FREE FIRE  SERVER 1 VS 1 CH...    415677
# 26  2021-05-27  Top 4 Indian Defence News Headlines on Today's...     89309
# 27  2021-05-26  India Alert - इंडिया अलर्ट - New Episode 528 -...    582241
# 28  2021-05-26  YA ME SIGUES EN MIS REDES SOCIALES?\n\nINSTAGR...     54954
# 29  2021-05-29  Go to https://NordVPN.com/dhruv and use code D...    764075
# 30  2021-05-26  Two hundred fifty thousand infections and four...     44291
# 31  2021-05-26  Cyclone Yaas has started making landfall on In...    161544
# 32  2021-05-24  India Alert - इंडिया अलर्ट - New Episode 527 -...   1187622
# 33  2021-05-25  Police in India are investigating Twitter, aft...     56908
# 34  2021-05-30  #Hamirpur #UPNews #HeadlinesIndia\nमहिला दारोग...     37618
# 35  2021-05-29  din bhar ki khabar | news of the day, hindi ne...    327192
# 36  2021-05-29  Reaction Gear: https://amzn.to/2QgTwk2 (affili...     52731
# 37  2021-05-28  India has reported thousands of "black fungus"...      5843
# 38  2021-05-27  While children are unlikely to fall severely i...     29705
# 39  2021-05-30  Time to see who will win the World Test Champi...     66678
# 40  2021-05-26  There's been concern around the world about th...     58889
# 41  2021-05-23  If the last frame isn't life goals, we don't k...   1718528
# 42  2021-05-28  din bhar ki khabar | news of the day, hindi ne...    348268
# 43  2021-05-24  Subscribe to our YouTube channel for free here...    567759
# 44  2021-05-26  India’s lowest caste, known as Dalits, and oth...     41697
# 45  2021-05-27  #India #vaccine #TokyoOlympics #TaiwanChinaBio...    214928
# 46  2021-05-29  The rare fungal disease mucormycosis has kille...      9534
# 47  2021-05-26  WhatsApp is suing the Indian government over n...    116243
# 48  2021-05-27  Some memories are always special! \nPre-Regist...   3990643
# 49  2021-05-27  Los niños, especialmente los de las comunidade...     36937
#
#    likeCount dislikeCount favoriteCount commentCount Category
# 0        804           19             0           36    INDIA
# 1       1416          153             0           56    INDIA
# 2        657          147             0          661    INDIA
# 3        534           21             0           32    INDIA
# 4        167           20             0          207    INDIA
# 5       1633          161             0          100    INDIA
# 6       5328          298             0          747    INDIA
# 7       2147          973             0         2592    INDIA
# 8        224           33             0          191    INDIA
# 9      34080         2293             0         3976    INDIA
# 10     30416          831             0         2042    INDIA
# 11       889          450             0          914    INDIA
# 12       226           35             0          NaN    INDIA
# 13      4341           53             0          288    INDIA
# 14      5365           40             0          178    INDIA
# 15       830          151             0          414    INDIA
# 16       382           23             0           28    INDIA
# 17      9762          437             0         2224    INDIA
# 18       192          116             0          166    INDIA
# 19    368237         6738             0        42331    INDIA
# 20       429           56             0          258    INDIA
# 21        41           12             0            9    INDIA
# 22       701           58             0          284    INDIA
# 23      9350          242             0         1088    INDIA
# 24       615           64             0           31    INDIA
# 25     38203          594             0          303    INDIA
# 26      5083           54             0          316    INDIA
# 27      3449          772             0          118    INDIA
# 28      3622           52             0          435    INDIA
# 29     60667         1794             0         4648    INDIA
# 30       537          127             0          NaN    INDIA
# 31      1781          157             0          899    INDIA
# 32      6619         1645             0          211    INDIA
# 33      1706          584             0         1536    INDIA
# 34      1497           50             0          104    INDIA
# 35      5921          558             0          140    INDIA
# 36      2665           67             0          472    INDIA
# 37       102           13             0           67    INDIA
# 38       316           35             0          185    INDIA
# 39      5556          184             0           25    INDIA
# 40       342          301             0          NaN    INDIA
# 41    110003         2333             0         1667    INDIA
# 42      6091          584             0          116    INDIA
# 43      3962          307             0         2689    INDIA
# 44      1114           93             0          657    INDIA
# 45       359          684             0          515    INDIA
# 46       139            7             0           35    INDIA
# 47      2871          220             0         1646    INDIA
# 48    604198         5977             0        46906    INDIA
# 49       838           16             0           94    INDIA

# %%
dataframe['v_title'][0]
# Out:
# 'क्यों रो पड़ा Pawandeep अपनी Singing के वक़्त? | Indian Idol | Contestant Mashup'

# %%
dataframe.to_csv('data_31.csv',encoding='utf-8')
